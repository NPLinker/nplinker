# %%
# Running at commit 30e3836987dcf62c37fc47f0115dc614710fe51b

# %%
# %reload_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import os
import numpy

from nplinker import nplinker
from nplinker import logconfig
logconfig.LogConfig.setLogLevel('DEBUG') # 'INFO' is a lot less spammy
from nplinker.scoring import IOKR
# Out:
# ['/home/grimur/miniconda2/envs/jupyter-py3/lib/python3.7/site-packages/cdk_pywrapper']
# Server process already running: True

# %%
# This is the original Crusemann data folder

# %%
npl = nplinker.NPLinker('/home/grimur/data-crusemann/nplinker_crusemann_20200131/crusemann_new.toml')
# Out:
# 15:58:31 [DEBUG] config.py:83, Parsing default config file: /home/grimur/.config/nplinker/nplinker.toml
# 15:58:31 [DEBUG] config.py:86, Loading user config /home/grimur/data-crusemann/nplinker_crusemann_20200131/crusemann_new.toml
# 15:58:31 [INFO] config.py:121, Loading from local data in directory /home/grimur/data-crusemann/nplinker_crusemann_26112019
# 15:58:31 [DEBUG] loader.py:108, DatasetLoader(/home/grimur/data-crusemann/nplinker_crusemann_26112019, , False)

# %%
npl.load_data()
# Out:
# 15:58:32 [DEBUG] nplinker.py:212, load_data (normal case, full load)
# 15:58:32 [WARNING] loader.py:29, WARNING: unable to find extra_nodes_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/quantification_table_reformatted/*.csv"
# 15:58:32 [WARNING] loader.py:29, WARNING: unable to find metadata_table_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/metadata_table/metadata_table*.txt"
# 15:58:32 [WARNING] loader.py:29, WARNING: unable to find quantification_table_file in path "/home/grimur/data-crusemann/nplinker_crusemann_26112019/quantification_table/quantification_table*.csv"
# 15:58:32 [INFO] loader.py:353, Loaded global strain IDs (0 total)
# 15:58:32 [INFO] loader.py:361, Loaded dataset strain IDs (144 total)
# 15:58:33 [INFO] metabolomics.py:643, 6246 molecules parsed from MGF file
# 15:58:33 [DEBUG] metabolomics.py:358, loading edges file: /home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/networkedges_selfloop/865b124c09b44db78c7d4c296a57d9ea.pairsinfo [6246 spectra from MGF]
# /home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/clusterinfosummarygroup_attributes_withIDs_withcomponentID/b270f7e260f34e808ead3f642784b672.tsv True
# 15:58:33 [INFO] metabolomics.py:660, Found older-style GNPS dataset, no quantification table
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: neg-3-Me.mzXML for cluster index 110002
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain:  for cluster index 110002
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_A1_M.mzXML for cluster index 73461
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_R5_B.mzXML for cluster index 55341
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 16a.mzXML for cluster index 105000
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_A1_E.mzXML for cluster index 105007
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_R5_M.mzXML for cluster index 21618
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_MS_E.mzXML for cluster index 37791
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_R5_E.mzXML for cluster index 37791
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_MS_B.mzXML for cluster index 122382
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_MS_E.mzXML for cluster index 77289
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_MS_M.mzXML for cluster index 77289
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_R5_M.mzXML for cluster index 77289
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: neg-3-EA.mzXML for cluster index 77289
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_A1_E.mzXML for cluster index 100373
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: neg-3-Bu.mzXML for cluster index 101530
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: JAN30_12B.mzXML for cluster index 124723
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: S801-3-Me.mzXML for cluster index 42159
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_R5_E.mzXML for cluster index 12224
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_A1_B.mzXML for cluster index 59626
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: CNQ149_MS_B.mzXML for cluster index 21428
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_A1_M.mzXML for cluster index 63043
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 36b.mzXML for cluster index 45469
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_A1_B.mzXML for cluster index 70646
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: S801-3-Bu.mzXML for cluster index 38198
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: H643-3-Bu.mzXML for cluster index 41544
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 16b.mzXML for cluster index 109461
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 36a.mzXML for cluster index 124662
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 5b.mzXML for cluster index 124662
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: H643-3-Me.mzXML for cluster index 56845
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 17b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 15b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 13a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 18b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 22b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 15a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 18a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 13b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 22a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 17a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 19a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 14a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 12c.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 7a.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 19c.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 21c.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 14b.mzXML for cluster index 52340
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: -ve_R5_B.mzXML for cluster index 154
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: &#127;CNY228_MS_E.mzXML for cluster index 32725
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 40a.mzXML for cluster index 33728
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 26a.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 34c.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 36c.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 34b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 34a.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 32b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 41a.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 32c.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 28b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 35a.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 25b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 25c.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 37b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 27a.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 38b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 37c.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 35b.mzXML for cluster index 62336
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 38a.mzXML for cluster index 44972
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 5a.mzXML for cluster index 116143
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 6a.mzXML for cluster index 80280
# 15:58:33 [WARNING] metabolomics.py:536, Unknown strain: 40b.mzXML for cluster index 121459
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 42b.mzXML for cluster index 95477
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: S801-3-EA.mzXML for cluster index 13340
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: H643-3-EA.mzXML for cluster index 13340
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 26c.mzXML for cluster index 58621
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 35c.mzXML for cluster index 58621
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 28a.mzXML for cluster index 58621
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 29a.mzXML for cluster index 59110
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 29c.mzXML for cluster index 59110
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 27b.mzXML for cluster index 59110
# 15:58:34 [WARNING] metabolomics.py:536, Unknown strain: 12b.mzXML for cluster index 93250
# 15:58:34 [WARNING] metabolomics.py:551, 81 unknown strains were detected a total of 8194 times
# 15:58:34 [DEBUG] metabolomics.py:701, make_families: 494 molams + 2600 singletons
# 15:58:34 [INFO] loader.py:339, Loading provided annotation files (/home/grimur/data-crusemann/nplinker_crusemann_26112019/DB_result)
# 15:58:34 [DEBUG] annotations.py:57, Parsed 0 annotations configuration entries
# 15:58:34 [DEBUG] annotations.py:65, Found 0 annotations .tsv files in /home/grimur/data-crusemann/nplinker_crusemann_26112019/DB_result
# 15:58:34 [DEBUG] loader.py:249, make_mibig_bgc_dict(/home/grimur/data-crusemann/nplinker_crusemann_26112019/mibig_json)
# 15:58:34 [INFO] genomics.py:366, Found 1816 MiBIG json files
# 15:58:38 [DEBUG] loader.py:251, mibig_bgc_dict has 1816 entries
# 15:58:38 [DEBUG] loader.py:310, Generating antiSMASH filename cache...
# 15:58:47 [DEBUG] loader.py:321, Cache generation took 8.890s
# 15:58:47 [DEBUG] loader.py:323, loadBGC_from_cluster_files(antismash_dir=/home/grimur/iokr_verify_data/crusemann/antismash)
# 15:58:47 [INFO] genomics.py:273, # MiBIG BGCs = 0, non-MiBIG BGCS = 5132, total bgcs = 5132, GCFs = 454, strains=1960
# 15:58:47 [INFO] genomics.py:329, Filtering MiBIG BGCs: removing 0 GCFs and 0 BGCs
# 15:58:47 [INFO] genomics.py:280, # after filtering, total bgcs = 3316, GCFs = 454, strains=144
# 15:58:47 [DEBUG] genomics.py:284, Loading .network files
# 15:58:47 [INFO] loader.py:226, Strains filtered down to total of 118
# 15:58:47 [DEBUG] nplinker.py:236, Generating lookup tables: genomics
# 15:58:47 [DEBUG] nplinker.py:248, Generating lookup tables: metabolomics
# 15:58:47 [DEBUG] nplinker.py:257, load_data: completed
# True

# %%
# ...and this is hacking the 'new' crusemann data on top of that (DL'd from paired data platform)
# Should be able to load this on the fly, but...

# %%
#from nplinker.metabolomics import load_spectra
#mgf_path = '/home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/METABOLOMICS-SNETS-9360fa51-download_clustered_spectra-main.mgf'
#npl._spectra = load_spectra(mgf_path)

# %%
# bigscape_path = '/home/grimur/iokr_verify_data/crusemann/bigscape/network_files/2020-01-23_16-38-00_hybrids_glocal/'

# %%
# npl._loader.bigscape_dir = bigscape_path
# npl._loader._load_strain_mappings()
# npl._loader._load_genomics()

# %%
# npl._bgcs = npl._loader.bgcs
# npl._gcfs = npl._loader.gcfs
# npl._strains = npl._loader.strains

# %%
import csv

# %%
gnps_spectrum_file = "/home/grimur/iokr_verify_data/crusemann/extracted/MSV000078836/clusterinfosummarygroup_attributes_withIDs_withcomponentID/b270f7e260f34e808ead3f642784b672.tsv"
spectra_to_strains = {}
with open(gnps_spectrum_file, 'r') as f:
    r = csv.reader(f, delimiter="\t")
    header = next(r)
    id_column = header.index('cluster index')
    strain_columns = [x for x in range(len(header)) if header[x].startswith('C') and len(header[x]) == 6]
    for line in r:
        spectrum_id = line[id_column]
        member_strains = [header[x] for x in range(len(line)) if line[x] != '0' and x in strain_columns]
        spectra_to_strains[int(spectrum_id)] = member_strains

# %%
from nplinker.parsers.kcb import KCBParser

# %%
kkb_bgc_hits = {}
for bgc in npl.bgcs:
    kcb_filename = KCBParser.get_kcb_filename_from_bgc(bgc)
    kcb_parser = KCBParser(kcb_filename)
    hits = []
    for mibig_id, hit in kcb_parser.hits.items():
        score = numpy.sum([x['blast_score'] for x in hit['individual_hits']])
        hits.append((mibig_id, score))
    if len(hits) > 0:
        kkb_bgc_hits[bgc] = hits

# %%
print(len(kkb_bgc_hits))
# Out:
# 2808

# %%
# These are the links from the paired data platform - so, _verified_ links!!!

# %%
established_links = [
    ('CNS205', 'BGC0000827', 206),
    ('CNS205', 'BGC0000333', 489),
    ('CNB440', 'BGC0000940', 25),
    ('CNB440', 'BGC0000241', 381),
    ('CNT005', 'BGC0001228', 492),
    ('CNS205', 'BGC0000137', 353),
    ('CNS205', 'BGC0000137', 358),
    ('CNS237', 'BGC0001830', 309)
]

# %%
established_link_objects = []
for bgc, kkb_hits in kkb_bgc_hits.items():
    for strain_id, mibig_id, molfam_id in established_links:
        if strain_id == bgc.strain.id or strain_id in bgc.strain.aliases:
            if mibig_id in [x[0] for x in kkb_hits if x[1] > 10000]:
                for molecular_family in npl.molfams:
                    if molecular_family.family_id == molfam_id:
                        for spectrum in molecular_family.spectra:
                            # If we want to do this properly (i.e. using the strain objects on the spectra themselves) then this is broken!
                            if strain_id not in spectra_to_strains[spectrum.spectrum_id]:
                                continue
                            print(strain_id, mibig_id, spectrum.spectrum_id)
                            established_link_objects.append((bgc, spectrum))
                        
                """        
                for spectrum in npl.spectra:
                    # TODO: This is the wrong ID!!! Should be spectrum.spectrum_id!!!
                    print(spectrum_id, spectrum.spectrum_id)
                    if spectrum.spectrum_id == spectrum_id:
                        print(strain_id, mibig_id, spectrum_id)
                        p.add((strain_id, mibig_id))
                        q.add(spectrum_id)
                        established_link_objects.append((bgc, spectrum))
"""
# Out:
# CNS205 BGC0000137 72702
# CNS205 BGC0000137 72970
# CNS205 BGC0000137 73005
# CNS205 BGC0000137 70606
# CNS205 BGC0000137 75146
# CNS205 BGC0000137 75653
# CNS205 BGC0000137 72702
# CNS205 BGC0000137 72970
# CNS205 BGC0000137 73005
# CNS205 BGC0000137 70606
# CNS205 BGC0000137 75146
# CNS205 BGC0000137 75653
# CNS205 BGC0000333 120697
# CNS205 BGC0000333 121052
# CNS205 BGC0000333 121600
# CNS205 BGC0000333 122023
# CNT005 BGC0001228 123724
# CNT005 BGC0001228 123881
# CNT005 BGC0001228 123903
# CNS205 BGC0000827 41257
# CNS205 BGC0000827 41544
# CNS205 BGC0000827 44160
# CNS205 BGC0000827 44161
# CNS205 BGC0000827 44982
# CNS237 BGC0001830 58728
# CNS237 BGC0001830 62174
# CNS237 BGC0001830 63507
# CNS237 BGC0001830 63775
# CNS237 BGC0001830 65471
# CNS237 BGC0001830 66182
# CNS237 BGC0001830 66400
# CNS237 BGC0001830 67887
# CNS237 BGC0001830 68743
# CNS237 BGC0001830 93193
# CNS237 BGC0001830 99743
# CNS237 BGC0001830 100852
# CNS237 BGC0001830 101071
# CNB440 BGC0000241 77475
# CNB440 BGC0000241 84491

# %%
len(established_link_objects)
# Out:
# 39

# %%
import csv
bgc_structures = {}
with open('/home/grimur/iokr/data/mibig/compunds_structures_2.0.csv') as f:
    r = csv.reader(f)
    for line in r:
        bgc_id, compound_name, smiles, database_ids = line
        if not bgc_id.startswith('BGC'):
            continue
        if bgc_id in bgc_structures:
            bgc_structures[bgc_id].append(smiles)
        else:
            bgc_structures[bgc_id] = [smiles]

# %%
scores_thresh = 10000
bgc_smiles = []
bgc_smiles_index = []
bgc_smiles_scores = []

bgc_smiles_lookup = {}

#debug with only members of known links
#bgc_list = [x[0] for x in established_link_objects]
bgc_list = npl.bgcs
for bgc_idx, bgc in enumerate(bgc_list):
    current_bgc_smiles = set([])
    if bgc in kkb_bgc_hits:
        kkb_bgc = kkb_bgc_hits[bgc][0][0]
        smiles_list = bgc_structures[kkb_bgc]
        for smiles in smiles_list:
            if smiles != '':
                current_bgc_smiles.add(smiles)
        """
        for kkb_bgc, score in kkb_bgc_hits[bgc]:
            if kkb_bgc in bgc_structures:
                smiles_list = bgc_structures[kkb_bgc]
                bgc_smiles_scores.append(score)
                if score < scores_thresh:
                    continue
                for smiles in smiles_list:
                    if smiles != '':
                        current_bgc_smiles.add(smiles)"""
                        
    bgc_smiles_lookup[bgc] = current_bgc_smiles
                
    for smiles in current_bgc_smiles:
        bgc_smiles.append(smiles)
        bgc_smiles_index.append(bgc_idx)

# %%
print('total bgc with associated structure: {}'.format(len(set(bgc_smiles_index))))
print('total bgcs: {}'.format(len(npl.bgcs)))
print('total spectra: {}'.format(len(npl.spectra)))
# Out:
# total bgc with associated structure: 2242
# total bgcs: 3316
# total spectra: 6246

# %%
reverse_smiles_lookup = {}
for smiles, bgc_idx in zip(bgc_smiles, bgc_smiles_index):
    if smiles not in reverse_smiles_lookup:
        reverse_smiles_lookup[smiles] = []
    reverse_smiles_lookup[smiles].append(bgc_idx)

# %%
smiles_list = list(reverse_smiles_lookup.keys())

# %%
from nplinker.scoring.iokr import nplinker_iokr

# %%
iokr_server = nplinker_iokr.get_iokr_server()
# Out:
# 11:35:04 [DEBUG] nplinker_iokr.py:118, Init IOKR data server
# 11:35:04 [DEBUG] iokrdata.py:202, IOKRDataServer __init__
# 11:35:04 [DEBUG] iokrdata.py:38, GNPS __init__
# 11:35:05 [DEBUG] iokrdata.py:210, No kernel specified. Please initialise manually.
# 11:35:05 [DEBUG] nplinker_iokr.py:123, Init kernel values
# 11:35:08 [DEBUG] nplinker_iokr.py:128, Load MS files
# 11:35:08 [DEBUG] iokrdata.py:226, IOKRDataServer load_ms_files
# 11:35:08 [DEBUG] iokrdata.py:228, Loading cached MS data
# 11:35:09 [DEBUG] iokrdata.py:232, Done in 1.162266s
# 11:35:09 [DEBUG] nplinker_iokr.py:151, Configure kernel
# 11:35:09 [DEBUG] nplinker_iokr.py:156, Set fingerprint
# 11:35:09 [DEBUG] iokrdata.py:327, IOKRDataServer set_fingerprint
# 11:35:09 [DEBUG] iokrdata.py:335, fpfile is "/home/grimur/git/nplinker/nplinker/prototype/nplinker/scoring/iokr/data/fp_None_gnps.bin.npy"
# 11:35:09 [DEBUG] iokrdata.py:337, Loading GNPS fingerprints from file
# 11:35:09 [DEBUG] iokrdata.py:69, GNPS set_fingerprint_from_file
# 11:35:11 [DEBUG] nplinker_iokr.py:162, fit()
# 11:35:13 [DEBUG] iokrdata.py:51, GNPS get_fingerprints
# 11:35:13 [DEBUG] nplinker_iokr.py:168, get_iokr_server complete!

# %%
from nplinker.scoring.iokr.spectrum import MSSpectrum

# %%
# Debug with only members of known links
# spectra_list = [x[1] for x in established_link_objects]
spectra_list = npl.spectra
spl = [MSSpectrum(spec=x) for x in spectra_list]

# %%
# first cached results

# %%
rank = iokr_server.score_smiles(spl, smiles_list)
# Out:
# 11:35:25 [DEBUG] nplinker_iokr.py:39, cache miss
# 11:35:25 [DEBUG] nplinker_iokr.py:40, Calculate fingerprints for candidate set
# 11:35:25 [DEBUG] nplinker_iokr.py:44, done 0/273
# 11:35:26 [DEBUG] nplinker_iokr.py:44, done 1/273
# 11:35:26 [DEBUG] nplinker_iokr.py:44, done 2/273
# 11:35:27 [DEBUG] nplinker_iokr.py:44, done 3/273
# 11:35:27 [DEBUG] nplinker_iokr.py:44, done 4/273
# 11:35:27 [DEBUG] nplinker_iokr.py:44, done 5/273
# 11:35:28 [DEBUG] nplinker_iokr.py:44, done 6/273
# 11:35:28 [DEBUG] nplinker_iokr.py:44, done 7/273
# 11:35:29 [DEBUG] nplinker_iokr.py:44, done 8/273
# 11:35:29 [DEBUG] nplinker_iokr.py:44, done 9/273
# 11:35:30 [DEBUG] nplinker_iokr.py:44, done 10/273
# 11:35:30 [DEBUG] nplinker_iokr.py:44, done 11/273
# 11:35:30 [DEBUG] nplinker_iokr.py:44, done 12/273
# 11:35:31 [DEBUG] nplinker_iokr.py:44, done 13/273
# 11:35:31 [DEBUG] nplinker_iokr.py:44, done 14/273
# 11:35:31 [DEBUG] nplinker_iokr.py:44, done 15/273
# 11:35:32 [DEBUG] nplinker_iokr.py:44, done 16/273
# 11:35:32 [DEBUG] nplinker_iokr.py:44, done 17/273
# 11:35:33 [DEBUG] nplinker_iokr.py:44, done 18/273
# 11:35:33 [DEBUG] nplinker_iokr.py:44, done 19/273
# 11:35:33 [DEBUG] nplinker_iokr.py:44, done 20/273
# 11:35:34 [DEBUG] nplinker_iokr.py:44, done 21/273
# 11:35:34 [DEBUG] nplinker_iokr.py:44, done 22/273
# 11:35:34 [DEBUG] nplinker_iokr.py:44, done 23/273
# 11:35:35 [DEBUG] nplinker_iokr.py:44, done 24/273
# 11:35:35 [DEBUG] nplinker_iokr.py:44, done 25/273
# 11:35:35 [DEBUG] nplinker_iokr.py:44, done 26/273
# 11:35:36 [DEBUG] nplinker_iokr.py:44, done 27/273
# 11:35:36 [DEBUG] nplinker_iokr.py:44, done 28/273
# 11:35:36 [DEBUG] nplinker_iokr.py:44, done 29/273
# 11:35:37 [DEBUG] nplinker_iokr.py:44, done 30/273
# 11:35:37 [DEBUG] nplinker_iokr.py:44, done 31/273
# 11:35:37 [DEBUG] nplinker_iokr.py:44, done 32/273
# 11:35:38 [DEBUG] nplinker_iokr.py:44, done 33/273
# 11:35:38 [DEBUG] nplinker_iokr.py:44, done 34/273
# 11:35:38 [DEBUG] nplinker_iokr.py:44, done 35/273
# 11:35:39 [DEBUG] nplinker_iokr.py:44, done 36/273
# 11:35:39 [DEBUG] nplinker_iokr.py:44, done 37/273
# 11:35:40 [DEBUG] nplinker_iokr.py:44, done 38/273
# 11:35:40 [DEBUG] nplinker_iokr.py:44, done 39/273
# 11:35:40 [DEBUG] nplinker_iokr.py:44, done 40/273
# 11:35:41 [DEBUG] nplinker_iokr.py:44, done 41/273
# 11:35:41 [DEBUG] nplinker_iokr.py:44, done 42/273
# 11:35:41 [DEBUG] nplinker_iokr.py:44, done 43/273
# 11:35:42 [DEBUG] nplinker_iokr.py:44, done 44/273
# 11:35:42 [DEBUG] nplinker_iokr.py:44, done 45/273
# 11:35:42 [DEBUG] nplinker_iokr.py:44, done 46/273
# 11:35:43 [DEBUG] nplinker_iokr.py:44, done 47/273
# 11:35:43 [DEBUG] nplinker_iokr.py:44, done 48/273
# 11:35:44 [DEBUG] nplinker_iokr.py:44, done 49/273
# 11:35:44 [DEBUG] nplinker_iokr.py:44, done 50/273
# 11:35:44 [DEBUG] nplinker_iokr.py:44, done 51/273
# 11:35:45 [DEBUG] nplinker_iokr.py:44, done 52/273
# 11:35:45 [DEBUG] nplinker_iokr.py:44, done 53/273
# 11:35:46 [DEBUG] nplinker_iokr.py:44, done 54/273
# 11:35:46 [DEBUG] nplinker_iokr.py:44, done 55/273
# 11:35:46 [DEBUG] nplinker_iokr.py:44, done 56/273
# 11:35:47 [DEBUG] nplinker_iokr.py:44, done 57/273
# 11:35:47 [DEBUG] nplinker_iokr.py:44, done 58/273
# 11:35:48 [DEBUG] nplinker_iokr.py:44, done 59/273
# 11:35:48 [DEBUG] nplinker_iokr.py:44, done 60/273
# 11:35:48 [DEBUG] nplinker_iokr.py:44, done 61/273
# 11:35:49 [DEBUG] nplinker_iokr.py:44, done 62/273
# 11:35:49 [DEBUG] nplinker_iokr.py:44, done 63/273
# 11:35:50 [DEBUG] nplinker_iokr.py:44, done 64/273
# 11:35:50 [DEBUG] nplinker_iokr.py:44, done 65/273
# 11:35:51 [DEBUG] nplinker_iokr.py:44, done 66/273
# 11:35:51 [DEBUG] nplinker_iokr.py:44, done 67/273
# 11:35:52 [DEBUG] nplinker_iokr.py:44, done 68/273
# 11:35:52 [DEBUG] nplinker_iokr.py:44, done 69/273
# 11:35:53 [DEBUG] nplinker_iokr.py:44, done 70/273
# 11:35:53 [DEBUG] nplinker_iokr.py:44, done 71/273
# 11:35:54 [DEBUG] nplinker_iokr.py:44, done 72/273
# 11:35:54 [DEBUG] nplinker_iokr.py:44, done 73/273
# 11:35:54 [DEBUG] nplinker_iokr.py:44, done 74/273
# 11:35:55 [DEBUG] nplinker_iokr.py:44, done 75/273
# 11:35:55 [DEBUG] nplinker_iokr.py:44, done 76/273
# 11:35:55 [DEBUG] nplinker_iokr.py:44, done 77/273
# 11:35:56 [DEBUG] nplinker_iokr.py:44, done 78/273
# 11:35:56 [DEBUG] nplinker_iokr.py:44, done 79/273
# 11:35:56 [DEBUG] nplinker_iokr.py:44, done 80/273
# 11:35:57 [DEBUG] nplinker_iokr.py:44, done 81/273
# 11:35:57 [DEBUG] nplinker_iokr.py:44, done 82/273
# 11:35:57 [DEBUG] nplinker_iokr.py:44, done 83/273
# 11:35:58 [DEBUG] nplinker_iokr.py:44, done 84/273
# 11:35:58 [DEBUG] nplinker_iokr.py:44, done 85/273
# 11:35:59 [DEBUG] nplinker_iokr.py:44, done 86/273
# 11:35:59 [DEBUG] nplinker_iokr.py:44, done 87/273
# 11:36:00 [DEBUG] nplinker_iokr.py:44, done 88/273
# 11:36:00 [DEBUG] nplinker_iokr.py:44, done 89/273
# 11:36:00 [DEBUG] nplinker_iokr.py:44, done 90/273
# 11:36:01 [DEBUG] nplinker_iokr.py:44, done 91/273
# 11:36:01 [DEBUG] nplinker_iokr.py:44, done 92/273
# 11:36:02 [DEBUG] nplinker_iokr.py:44, done 93/273
# 11:36:02 [DEBUG] nplinker_iokr.py:44, done 94/273
# 11:36:02 [DEBUG] nplinker_iokr.py:44, done 95/273
# 11:36:03 [DEBUG] nplinker_iokr.py:44, done 96/273
# 11:36:03 [DEBUG] nplinker_iokr.py:44, done 97/273
# 11:36:03 [DEBUG] nplinker_iokr.py:44, done 98/273
# 11:36:04 [DEBUG] nplinker_iokr.py:44, done 99/273
# 11:36:04 [DEBUG] nplinker_iokr.py:44, done 100/273
# 11:36:05 [DEBUG] nplinker_iokr.py:44, done 101/273
# 11:36:05 [DEBUG] nplinker_iokr.py:44, done 102/273
# 11:36:06 [DEBUG] nplinker_iokr.py:44, done 103/273
# 11:36:06 [DEBUG] nplinker_iokr.py:44, done 104/273
# 11:36:06 [DEBUG] nplinker_iokr.py:44, done 105/273
# 11:36:07 [DEBUG] nplinker_iokr.py:44, done 106/273
# 11:36:07 [DEBUG] nplinker_iokr.py:44, done 107/273
# 11:36:07 [DEBUG] nplinker_iokr.py:44, done 108/273
# 11:36:07 [DEBUG] nplinker_iokr.py:44, done 109/273
# 11:36:08 [DEBUG] nplinker_iokr.py:44, done 110/273
# 11:36:08 [DEBUG] nplinker_iokr.py:44, done 111/273
# 11:36:08 [DEBUG] nplinker_iokr.py:44, done 112/273
# 11:36:09 [DEBUG] nplinker_iokr.py:44, done 113/273
# 11:36:09 [DEBUG] nplinker_iokr.py:44, done 114/273
# 11:36:09 [DEBUG] nplinker_iokr.py:44, done 115/273
# 11:36:10 [DEBUG] nplinker_iokr.py:44, done 116/273
# 11:36:10 [DEBUG] nplinker_iokr.py:44, done 117/273
# 11:36:10 [DEBUG] nplinker_iokr.py:44, done 118/273
# 11:36:11 [DEBUG] nplinker_iokr.py:44, done 119/273
# 11:36:11 [DEBUG] nplinker_iokr.py:44, done 120/273
# 11:36:12 [DEBUG] nplinker_iokr.py:44, done 121/273
# 11:36:12 [DEBUG] nplinker_iokr.py:44, done 122/273
# 11:36:12 [DEBUG] nplinker_iokr.py:44, done 123/273
# 11:36:13 [DEBUG] nplinker_iokr.py:44, done 124/273
# 11:36:13 [DEBUG] nplinker_iokr.py:44, done 125/273
# 11:36:13 [DEBUG] nplinker_iokr.py:44, done 126/273
# 11:36:14 [DEBUG] nplinker_iokr.py:44, done 127/273
# 11:36:14 [DEBUG] nplinker_iokr.py:44, done 128/273
# 11:36:14 [DEBUG] nplinker_iokr.py:44, done 129/273
# 11:36:14 [DEBUG] nplinker_iokr.py:44, done 130/273
# 11:36:15 [DEBUG] nplinker_iokr.py:44, done 131/273
# 11:36:15 [DEBUG] nplinker_iokr.py:44, done 132/273
# 11:36:15 [DEBUG] nplinker_iokr.py:44, done 133/273
# 11:36:16 [DEBUG] nplinker_iokr.py:44, done 134/273
# 11:36:16 [DEBUG] nplinker_iokr.py:44, done 135/273
# 11:36:17 [DEBUG] nplinker_iokr.py:44, done 136/273
# 11:36:17 [DEBUG] nplinker_iokr.py:44, done 137/273
# 11:36:18 [DEBUG] nplinker_iokr.py:44, done 138/273
# 11:36:18 [DEBUG] nplinker_iokr.py:44, done 139/273
# 11:36:18 [DEBUG] nplinker_iokr.py:44, done 140/273
# 11:36:19 [DEBUG] nplinker_iokr.py:44, done 141/273
# 11:36:19 [DEBUG] nplinker_iokr.py:44, done 142/273
# 11:36:19 [DEBUG] nplinker_iokr.py:44, done 143/273
# 11:36:20 [DEBUG] nplinker_iokr.py:44, done 144/273
# 11:36:20 [DEBUG] nplinker_iokr.py:44, done 145/273
# 11:36:20 [DEBUG] nplinker_iokr.py:44, done 146/273
# 11:36:21 [DEBUG] nplinker_iokr.py:44, done 147/273
# 11:36:21 [DEBUG] nplinker_iokr.py:44, done 148/273
# 11:36:22 [DEBUG] nplinker_iokr.py:44, done 149/273
# 11:36:22 [DEBUG] nplinker_iokr.py:44, done 150/273
# 11:36:22 [DEBUG] nplinker_iokr.py:44, done 151/273
# 11:36:23 [DEBUG] nplinker_iokr.py:44, done 152/273
# 11:36:23 [DEBUG] nplinker_iokr.py:44, done 153/273
# 11:36:23 [DEBUG] nplinker_iokr.py:44, done 154/273
# 11:36:24 [DEBUG] nplinker_iokr.py:44, done 155/273
# 11:36:24 [DEBUG] nplinker_iokr.py:44, done 156/273
# 11:36:24 [DEBUG] nplinker_iokr.py:44, done 157/273
# 11:36:25 [DEBUG] nplinker_iokr.py:44, done 158/273
# 11:36:25 [DEBUG] nplinker_iokr.py:44, done 159/273
# 11:36:25 [DEBUG] nplinker_iokr.py:44, done 160/273
# 11:36:26 [DEBUG] nplinker_iokr.py:44, done 161/273
# 11:36:26 [DEBUG] nplinker_iokr.py:44, done 162/273
# 11:36:27 [DEBUG] nplinker_iokr.py:44, done 163/273
# 11:36:27 [DEBUG] nplinker_iokr.py:44, done 164/273
# 11:36:27 [DEBUG] nplinker_iokr.py:44, done 165/273
# 11:36:28 [DEBUG] nplinker_iokr.py:44, done 166/273
# 11:36:28 [DEBUG] nplinker_iokr.py:44, done 167/273
# 11:36:28 [DEBUG] nplinker_iokr.py:44, done 168/273
# 11:36:28 [DEBUG] nplinker_iokr.py:44, done 169/273
# 11:36:29 [DEBUG] nplinker_iokr.py:44, done 170/273
# 11:36:29 [DEBUG] nplinker_iokr.py:44, done 171/273
# 11:36:30 [DEBUG] nplinker_iokr.py:44, done 172/273
# 11:36:30 [DEBUG] nplinker_iokr.py:44, done 173/273
# 11:36:30 [DEBUG] nplinker_iokr.py:44, done 174/273
# 11:36:30 [DEBUG] nplinker_iokr.py:44, done 175/273
# 11:36:31 [DEBUG] nplinker_iokr.py:44, done 176/273
# 11:36:31 [DEBUG] nplinker_iokr.py:44, done 177/273
# 11:36:32 [DEBUG] nplinker_iokr.py:44, done 178/273
# 11:36:32 [DEBUG] nplinker_iokr.py:44, done 179/273
# 11:36:32 [DEBUG] nplinker_iokr.py:44, done 180/273
# 11:36:32 [DEBUG] nplinker_iokr.py:44, done 181/273
# 11:36:33 [DEBUG] nplinker_iokr.py:44, done 182/273
# 11:36:33 [DEBUG] nplinker_iokr.py:44, done 183/273
# 11:36:34 [DEBUG] nplinker_iokr.py:44, done 184/273
# 11:36:34 [DEBUG] nplinker_iokr.py:44, done 185/273
# 11:36:35 [DEBUG] nplinker_iokr.py:44, done 186/273
# 11:36:35 [DEBUG] nplinker_iokr.py:44, done 187/273
# 11:36:35 [DEBUG] nplinker_iokr.py:44, done 188/273
# 11:36:36 [DEBUG] nplinker_iokr.py:44, done 189/273
# 11:36:36 [DEBUG] nplinker_iokr.py:44, done 190/273
# 11:36:37 [DEBUG] nplinker_iokr.py:44, done 191/273
# 11:36:37 [DEBUG] nplinker_iokr.py:44, done 192/273
# 11:36:37 [DEBUG] nplinker_iokr.py:44, done 193/273
# 11:36:38 [DEBUG] nplinker_iokr.py:44, done 194/273
# 11:36:38 [DEBUG] nplinker_iokr.py:44, done 195/273
# 11:36:38 [DEBUG] nplinker_iokr.py:44, done 196/273
# 11:36:39 [DEBUG] nplinker_iokr.py:44, done 197/273
# 11:36:39 [DEBUG] nplinker_iokr.py:44, done 198/273
# 11:36:39 [DEBUG] nplinker_iokr.py:44, done 199/273
# 11:36:40 [DEBUG] nplinker_iokr.py:44, done 200/273
# 11:36:40 [DEBUG] nplinker_iokr.py:44, done 201/273
# 11:36:40 [DEBUG] nplinker_iokr.py:44, done 202/273
# 11:36:41 [DEBUG] nplinker_iokr.py:44, done 203/273
# 11:36:41 [DEBUG] nplinker_iokr.py:44, done 204/273
# 11:36:41 [DEBUG] nplinker_iokr.py:44, done 205/273
# 11:36:42 [DEBUG] nplinker_iokr.py:44, done 206/273
# 11:36:42 [DEBUG] nplinker_iokr.py:44, done 207/273
# 11:36:42 [DEBUG] nplinker_iokr.py:44, done 208/273
# 11:36:43 [DEBUG] nplinker_iokr.py:44, done 209/273
# 11:36:43 [DEBUG] nplinker_iokr.py:44, done 210/273
# 11:36:43 [DEBUG] nplinker_iokr.py:44, done 211/273
# 11:36:44 [DEBUG] nplinker_iokr.py:44, done 212/273
# 11:36:44 [DEBUG] nplinker_iokr.py:44, done 213/273
# 11:36:44 [DEBUG] nplinker_iokr.py:44, done 214/273
# 11:36:45 [DEBUG] nplinker_iokr.py:44, done 215/273
# 11:36:45 [DEBUG] nplinker_iokr.py:44, done 216/273
# 11:36:45 [DEBUG] nplinker_iokr.py:44, done 217/273
# 11:36:46 [DEBUG] nplinker_iokr.py:44, done 218/273
# 11:36:46 [DEBUG] nplinker_iokr.py:44, done 219/273
# 11:36:46 [DEBUG] nplinker_iokr.py:44, done 220/273
# 11:36:47 [DEBUG] nplinker_iokr.py:44, done 221/273
# 11:36:47 [DEBUG] nplinker_iokr.py:44, done 222/273
# 11:36:47 [DEBUG] nplinker_iokr.py:44, done 223/273
# 11:36:48 [DEBUG] nplinker_iokr.py:44, done 224/273
# 11:36:48 [DEBUG] nplinker_iokr.py:44, done 225/273
# 11:36:48 [DEBUG] nplinker_iokr.py:44, done 226/273
# 11:36:49 [DEBUG] nplinker_iokr.py:44, done 227/273
# 11:36:49 [DEBUG] nplinker_iokr.py:44, done 228/273
# 11:36:49 [DEBUG] nplinker_iokr.py:44, done 229/273
# 11:36:50 [DEBUG] nplinker_iokr.py:44, done 230/273
# 11:36:50 [DEBUG] nplinker_iokr.py:44, done 231/273
# 11:36:50 [DEBUG] nplinker_iokr.py:44, done 232/273
# 11:36:51 [DEBUG] nplinker_iokr.py:44, done 233/273
# 11:36:51 [DEBUG] nplinker_iokr.py:44, done 234/273
# 11:36:52 [DEBUG] nplinker_iokr.py:44, done 235/273
# 11:36:52 [DEBUG] nplinker_iokr.py:44, done 236/273
# 11:36:52 [DEBUG] nplinker_iokr.py:44, done 237/273
# 11:36:53 [DEBUG] nplinker_iokr.py:44, done 238/273
# 11:36:53 [DEBUG] nplinker_iokr.py:44, done 239/273
# 11:36:54 [DEBUG] nplinker_iokr.py:44, done 240/273
# 11:36:54 [DEBUG] nplinker_iokr.py:44, done 241/273
# 11:36:54 [DEBUG] nplinker_iokr.py:44, done 242/273
# 11:36:55 [DEBUG] nplinker_iokr.py:44, done 243/273
# 11:36:55 [DEBUG] nplinker_iokr.py:44, done 244/273
# 11:36:55 [DEBUG] nplinker_iokr.py:44, done 245/273
# 11:36:56 [DEBUG] nplinker_iokr.py:44, done 246/273
# 11:36:56 [DEBUG] nplinker_iokr.py:44, done 247/273
# 11:36:56 [DEBUG] nplinker_iokr.py:44, done 248/273
# 11:36:57 [DEBUG] nplinker_iokr.py:44, done 249/273
# 11:36:57 [DEBUG] nplinker_iokr.py:44, done 250/273
# 11:36:57 [DEBUG] nplinker_iokr.py:44, done 251/273
# 11:36:58 [DEBUG] nplinker_iokr.py:44, done 252/273
# 11:36:58 [DEBUG] nplinker_iokr.py:44, done 253/273
# 11:36:58 [DEBUG] nplinker_iokr.py:44, done 254/273
# 11:36:59 [DEBUG] nplinker_iokr.py:44, done 255/273
# 11:36:59 [DEBUG] nplinker_iokr.py:44, done 256/273
# 11:36:59 [DEBUG] nplinker_iokr.py:44, done 257/273
# 11:37:00 [DEBUG] nplinker_iokr.py:44, done 258/273
# 11:37:00 [DEBUG] nplinker_iokr.py:44, done 259/273
# 11:37:01 [DEBUG] nplinker_iokr.py:44, done 260/273
# 11:37:01 [DEBUG] nplinker_iokr.py:44, done 261/273
# 11:37:01 [DEBUG] nplinker_iokr.py:44, done 262/273
# 11:37:02 [DEBUG] nplinker_iokr.py:44, done 263/273
# 11:37:02 [DEBUG] nplinker_iokr.py:44, done 264/273
# 11:37:02 [DEBUG] nplinker_iokr.py:44, done 265/273
# 11:37:03 [DEBUG] nplinker_iokr.py:44, done 266/273
# 11:37:03 [DEBUG] nplinker_iokr.py:44, done 267/273
# 11:37:03 [DEBUG] nplinker_iokr.py:44, done 268/273
# 11:37:03 [DEBUG] nplinker_iokr.py:44, done 269/273
# 11:37:04 [DEBUG] nplinker_iokr.py:44, done 270/273
# 11:37:04 [DEBUG] nplinker_iokr.py:44, done 271/273
# 11:37:05 [DEBUG] nplinker_iokr.py:44, done 272/273
# 11:37:05 [DEBUG] nplinker_iokr.py:47, Extract latent basis
# 11:37:05 [DEBUG] nplinker_iokr.py:49, writing cache
# 11:37:05 [DEBUG] nplinker_iokr.py:54, Preprocessing candidate set FPs
# 11:38:15 [DEBUG] nplinker_iokr.py:58, Rank spectrum 0 (0/6246)
# 11:38:15 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:32 [DEBUG] nplinker_iokr.py:64, done (77.21521639823914)
# 11:39:32 [DEBUG] nplinker_iokr.py:65, project
# 11:39:32 [DEBUG] nplinker_iokr.py:69, done (0.052222490310668945)
# 11:39:32 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:32 [DEBUG] nplinker_iokr.py:58, Rank spectrum 1 (1/6246)
# 11:39:32 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:33 [DEBUG] nplinker_iokr.py:64, done (0.97951340675354)
# 11:39:33 [DEBUG] nplinker_iokr.py:65, project
# 11:39:33 [DEBUG] nplinker_iokr.py:69, done (0.0016789436340332031)
# 11:39:33 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:33 [DEBUG] nplinker_iokr.py:58, Rank spectrum 2 (2/6246)
# 11:39:33 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:34 [DEBUG] nplinker_iokr.py:64, done (0.993751049041748)
# 11:39:34 [DEBUG] nplinker_iokr.py:65, project
# 11:39:34 [DEBUG] nplinker_iokr.py:69, done (0.0014638900756835938)
# 11:39:34 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:34 [DEBUG] nplinker_iokr.py:58, Rank spectrum 3 (3/6246)
# 11:39:34 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:35 [DEBUG] nplinker_iokr.py:64, done (0.9897634983062744)
# 11:39:35 [DEBUG] nplinker_iokr.py:65, project
# 11:39:35 [DEBUG] nplinker_iokr.py:69, done (0.0014786720275878906)
# 11:39:35 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:35 [DEBUG] nplinker_iokr.py:58, Rank spectrum 4 (4/6246)
# 11:39:35 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:36 [DEBUG] nplinker_iokr.py:64, done (0.9971606731414795)
# 11:39:36 [DEBUG] nplinker_iokr.py:65, project
# 11:39:36 [DEBUG] nplinker_iokr.py:69, done (0.0014393329620361328)
# 11:39:36 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:36 [DEBUG] nplinker_iokr.py:58, Rank spectrum 5 (5/6246)
# 11:39:36 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:37 [DEBUG] nplinker_iokr.py:64, done (0.9717063903808594)
# 11:39:37 [DEBUG] nplinker_iokr.py:65, project
# 11:39:37 [DEBUG] nplinker_iokr.py:69, done (0.00164031982421875)
# 11:39:37 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:37 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6 (6/6246)
# 11:39:37 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:38 [DEBUG] nplinker_iokr.py:64, done (0.9748227596282959)
# 11:39:38 [DEBUG] nplinker_iokr.py:65, project
# 11:39:38 [DEBUG] nplinker_iokr.py:69, done (0.0015072822570800781)
# 11:39:38 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:38 [DEBUG] nplinker_iokr.py:58, Rank spectrum 7 (7/6246)
# 11:39:38 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:39 [DEBUG] nplinker_iokr.py:64, done (0.9841649532318115)
# 11:39:39 [DEBUG] nplinker_iokr.py:65, project
# 11:39:39 [DEBUG] nplinker_iokr.py:69, done (0.0015537738800048828)
# 11:39:39 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:39 [DEBUG] nplinker_iokr.py:58, Rank spectrum 8 (8/6246)
# 11:39:39 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:40 [DEBUG] nplinker_iokr.py:64, done (0.9824919700622559)
# 11:39:40 [DEBUG] nplinker_iokr.py:65, project
# 11:39:40 [DEBUG] nplinker_iokr.py:69, done (0.0015873908996582031)
# 11:39:40 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:40 [DEBUG] nplinker_iokr.py:58, Rank spectrum 9 (9/6246)
# 11:39:40 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:41 [DEBUG] nplinker_iokr.py:64, done (0.9828681945800781)
# 11:39:41 [DEBUG] nplinker_iokr.py:65, project
# 11:39:41 [DEBUG] nplinker_iokr.py:69, done (0.001641988754272461)
# 11:39:41 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:41 [DEBUG] nplinker_iokr.py:58, Rank spectrum 10 (10/6246)
# 11:39:41 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:39:42 [DEBUG] nplinker_iokr.py:64, done (0.9825551509857178)
# 11:39:42 [DEBUG] nplinker_iokr.py:65, project
# 11:39:42 [DEBUG] nplinker_iokr.py:69, done (0.0016045570373535156)
# 11:39:42 [DEBUG] nplinker_iokr.py:71, save distances
# 11:39:42 [DEBUG] nplinker_iokr.py:58, Rank spectrum 11 (11/6246)
# 11:39:42 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11
[DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:30 [DEBUG] nplinker_iokr.py:64, done (0.9955861568450928)
# 11:40:30 [DEBUG] nplinker_iokr.py:65, project
# 11:40:30 [DEBUG] nplinker_iokr.py:69, done (0.0015974044799804688)
# 11:40:30 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:30 [DEBUG] nplinker_iokr.py:58, Rank spectrum 60 (60/6246)
# 11:40:30 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:31 [DEBUG] nplinker_iokr.py:64, done (0.9758937358856201)
# 11:40:31 [DEBUG] nplinker_iokr.py:65, project
# 11:40:31 [DEBUG] nplinker_iokr.py:69, done (0.0015254020690917969)
# 11:40:31 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:31 [DEBUG] nplinker_iokr.py:58, Rank spectrum 61 (61/6246)
# 11:40:31 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:32 [DEBUG] nplinker_iokr.py:64, done (0.978630542755127)
# 11:40:32 [DEBUG] nplinker_iokr.py:65, project
# 11:40:32 [DEBUG] nplinker_iokr.py:69, done (0.0017015933990478516)
# 11:40:32 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:32 [DEBUG] nplinker_iokr.py:58, Rank spectrum 62 (62/6246)
# 11:40:32 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:33 [DEBUG] nplinker_iokr.py:64, done (0.9937648773193359)
# 11:40:33 [DEBUG] nplinker_iokr.py:65, project
# 11:40:33 [DEBUG] nplinker_iokr.py:69, done (0.001554727554321289)
# 11:40:33 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:33 [DEBUG] nplinker_iokr.py:58, Rank spectrum 63 (63/6246)
# 11:40:33 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:34 [DEBUG] nplinker_iokr.py:64, done (0.9986982345581055)
# 11:40:34 [DEBUG] nplinker_iokr.py:65, project
# 11:40:34 [DEBUG] nplinker_iokr.py:69, done (0.0016062259674072266)
# 11:40:34 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:34 [DEBUG] nplinker_iokr.py:58, Rank spectrum 64 (64/6246)
# 11:40:34 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:35 [DEBUG] nplinker_iokr.py:64, done (0.9947469234466553)
# 11:40:35 [DEBUG] nplinker_iokr.py:65, project
# 11:40:35 [DEBUG] nplinker_iokr.py:69, done (0.0018086433410644531)
# 11:40:35 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:35 [DEBUG] nplinker_iokr.py:58, Rank spectrum 65 (65/6246)
# 11:40:35 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:36 [DEBUG] nplinker_iokr.py:64, done (0.9899804592132568)
# 11:40:36 [DEBUG] nplinker_iokr.py:65, project
# 11:40:36 [DEBUG] nplinker_iokr.py:69, done (0.0016710758209228516)
# 11:40:36 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:36 [DEBUG] nplinker_iokr.py:58, Rank spectrum 66 (66/6246)
# 11:40:36 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11:40:37 [DEBUG] nplinker_iokr.py:64, done (0.9810645580291748)
# 11:40:37 [DEBUG] nplinker_iokr.py:65, project
# 11:40:37 [DEBUG] nplinker_iokr.py:69, done (0.0015218257904052734)
# 11:40:37 [DEBUG] nplinker_iokr.py:71, save distances
# 11:40:37 [DEBUG] nplinker_iokr.py:58, Rank spectrum 67 (67/6246)
# 11:40:37 [DEBUG] nplinker_iokr.py:60, kernel vector
# 11
[DEBUG] nplinker_iokr.py:58, Rank spectrum 6240 (6240/6246)
# 13:22:15 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:16 [DEBUG] nplinker_iokr.py:64, done (0.9653787612915039)
# 13:22:16 [DEBUG] nplinker_iokr.py:65, project
# 13:22:16 [DEBUG] nplinker_iokr.py:69, done (0.001550912857055664)
# 13:22:16 [DEBUG] nplinker_iokr.py:71, save distances
# 13:22:16 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6241 (6241/6246)
# 13:22:16 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:17 [DEBUG] nplinker_iokr.py:64, done (0.9695367813110352)
# 13:22:17 [DEBUG] nplinker_iokr.py:65, project
# 13:22:17 [DEBUG] nplinker_iokr.py:69, done (0.0015413761138916016)
# 13:22:17 [DEBUG] nplinker_iokr.py:71, save distances
# 13:22:17 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6242 (6242/6246)
# 13:22:17 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:18 [DEBUG] nplinker_iokr.py:64, done (0.968259334564209)
# 13:22:18 [DEBUG] nplinker_iokr.py:65, project
# 13:22:18 [DEBUG] nplinker_iokr.py:69, done (0.0015227794647216797)
# 13:22:18 [DEBUG] nplinker_iokr.py:71, save distances
# 13:22:18 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6243 (6243/6246)
# 13:22:18 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:19 [DEBUG] nplinker_iokr.py:64, done (0.9866371154785156)
# 13:22:19 [DEBUG] nplinker_iokr.py:65, project
# 13:22:19 [DEBUG] nplinker_iokr.py:69, done (0.0015926361083984375)
# 13:22:19 [DEBUG] nplinker_iokr.py:71, save distances
# 13:22:19 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6244 (6244/6246)
# 13:22:19 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:20 [DEBUG] nplinker_iokr.py:64, done (0.9800348281860352)
# 13:22:20 [DEBUG] nplinker_iokr.py:65, project
# 13:22:20 [DEBUG] nplinker_iokr.py:69, done (0.001491546630859375)
# 13:22:20 [DEBUG] nplinker_iokr.py:71, save distances
# 13:22:20 [DEBUG] nplinker_iokr.py:58, Rank spectrum 6245 (6245/6246)
# 13:22:20 [DEBUG] nplinker_iokr.py:60, kernel vector
# 13:22:21 [DEBUG] nplinker_iokr.py:64, done (0.975193977355957)
# 13:22:21 [DEBUG] nplinker_iokr.py:65, project
# 13:22:21 [DEBUG] nplinker_iokr.py:69, done (0.0017993450164794922)
# 13:22:21 [DEBUG] nplinker_iokr.py:71, save distances

# %%
# read from cache

# %%
import pickle
with open('saved_data.bin', 'rb') as f:
    rank, all_score_pairs, verified_score_pairs = pickle.load(f)

# %%
import pickle
with open('saved_data.bin', 'wb') as f:
    pickle.dump((rank, all_score_pairs, verified_score_pairs), f)

# %%
iokr_scores = rank

# %%
def get_iokr_score(mf, gcf):
    potential_scores = []
    for spectrum in mf.spectra:
        spectrum_idx = npl.spectra.index(spectrum)
        for bgc in gcf.bgcs:
            bgc_smiles_list = bgc_smiles_lookup[bgc]
            for smiles in bgc_smiles_list:
                smiles_index = smiles_list.index(smiles)
                spectrum_smiles_score = iokr_scores[spectrum_idx, smiles_index]
                potential_scores.append(spectrum_smiles_score)
    if len(potential_scores) == 0:
        return -100
    else:
        return max(potential_scores)

# %%
verified_bgc_mf_links = []
verified_bgc_mf_links_labels = []
for bgc, kkb_hits in kkb_bgc_hits.items():
    for strain_id, mibig_id, molfam_id in established_links:
        if strain_id == bgc.strain.id or strain_id in bgc.strain.aliases:
            if mibig_id in [x[0] for x in kkb_hits if x[1] > 10000]:
                for molecular_family in npl.molfams:
                    if molecular_family.family_id == molfam_id:
                        verified_bgc_mf_links.append((bgc, molecular_family))
                        verified_bgc_mf_links_labels.append(mibig_id)

# %%
from nplinker.scoring import misc
strains = npl.strains

# %%
all_score_pairs = []
verified_score_pairs = []

for i, gcf in enumerate(npl.gcfs):
    print("{} / {}".format(i, len(npl.gcfs)))
    
    for mf in npl.molfams:
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
        iokr_score = get_iokr_score(mf, gcf)
        
        all_score_pairs.append((metcalf_score, iokr_score))
        for link_bgc, link_mf in verified_bgc_mf_links:
            if link_bgc in gcf.bgcs and link_mf == mf:
                print('add verified')
                verified_score_pairs.append((metcalf_score, iokr_score))
# Out:
# 0 / 454
# 1 / 454
# 2 / 454
# 3 / 454
# 4 / 454
# 5 / 454
# 6 / 454
# 7 / 454
# 8 / 454
# 9 / 454
# 10 / 454
# 11 / 454
# 12 / 454
# 13 / 454
# 14 / 454
# 15 / 454
# 16 / 454
# 17 / 454
# 18 / 454
# 19 / 454
# 20 / 454
# 21 / 454
# 22 / 454
# 23 / 454
# 24 / 454
# 25 / 454
# 26 / 454
# 27 / 454
# 28 / 454
# 29 / 454
# 30 / 454
# 31 / 454
# 32 / 454
# 33 / 454
# 34 / 454
# 35 / 454
# 36 / 454
# 37 / 454
# 38 / 454
# 39 / 454
# 40 / 454
# 41 / 454
# 42 / 454
# 43 / 454
# 44 / 454
# 45 / 454
# 46 / 454
# 47 / 454
# 48 / 454
# add verified
# add verified
# 49 / 454
# 50 / 454
# 51 / 454
# 52 / 454
# 53 / 454
# 54 / 454
# 55 / 454
# 56 / 454
# 57 / 454
# 58 / 454
# 59 / 454
# 60 / 454
# 61 / 454
# 62 / 454
# 63 / 454
# 64 / 454
# 65 / 454
# 66 / 454
# 67 / 454
# 68 / 454
# 69 / 454
# 70 / 454
# 71 / 454
# add verified
# add verified
# 72 / 454
# 73 / 454
# 74 / 454
# 75 / 454
# 76 / 454
# 77 / 454
# 78 / 454
# 79 / 454
# 80 / 454
# 81 / 454
# 82 / 454
# 83 / 454
# 84 / 454
# 85 / 454
# 86 / 454
# 87 / 454
# 88 / 454
# 89 / 454
# 90 / 454
# 91 / 454
# 92 / 454
# 93 / 454
# 94 / 454
# 95 / 454
# 96 / 454
# 97 / 454
# 98 / 454
# 99 / 454
# 100 / 454
# 101 / 454
# 102 / 454
# 103 / 454
# 104 / 454
# 105 / 454
# 106 / 454
# 107 / 454
# 108 / 454
# 109 / 454
# 110 / 454
# 111 / 454
# 112 / 454
# 113 / 454
# 114 / 454
# 115 / 454
# 116 / 454
# 117 / 454
# 118 / 454
# 119 / 454
# 120 / 454
# 121 / 454
# 122 / 454
# 123 / 454
# add verified
# 313 / 454
# 314 / 454
# 315 / 454
# 316 / 454
# 317 / 454
# 318 / 454
# 319 / 454
# 320 / 454
# 321 / 454
# 322 / 454
# 323 / 454
# 324 / 454
# 325 / 454
# 326 / 454
# 327 / 454
# 328 / 454
# 329 / 454
# 330 / 454
# 331 / 454
# 332 / 454
# 333 / 454
# add verified
# add verified
# 334 / 454
# 335 / 454
# 336 / 454
# 337 / 454
# 338 / 454
# 339 / 454
# 340 / 454
# 341 / 454
# 342 / 454
# 343 / 454
# 344 / 454
# 345 / 454
# 346 / 454
# 347 / 454
# 348 / 454
# 349 / 454
# 350 / 454
# 351 / 454
# 352 / 454
# 353 / 454
# 354 / 454
# 355 / 454
# 356 / 454
# 357 / 454
# 358 / 454
# 359 / 454
# 360 / 454
# 361 / 454
# 362 / 454
# 363 / 454
# 364 / 454
# 365 / 454
# 366 / 454
# 367 / 454
# add verified
# add verified
# 368 / 454
# 369 / 454
# 370 / 454
# 371 / 454
# 372 / 454
# 373 / 454
# 374 / 454
# 375 / 454
# 376 / 454
# 377 / 454
# add verified
# 378 / 454
# 379 / 454
# 380 / 454
# 381 / 454
# 382 / 454
# 383 / 454
# 384 / 454
# 385 / 454
# 386 / 454
# 387 / 454
# 388 / 454
# 389 / 454
# 390 / 454
# 391 / 454
# 392 / 454
# 393 / 454
# 394 / 454
# 395 / 454
# 396 / 454
# 397 / 454
# 398 / 454
# 399 / 454
# 400 / 454
# 401 / 454
# 402 / 454
# 403 / 454
# 404 / 454
# 405 / 454
# 406 / 454
# 407 / 454
# 408 / 454
# 409 / 454
# 410 / 454
# 411 / 454
# 412 / 454
# 413 / 454
# 414 / 454
# 415 / 454
# 416 / 454
# 417 / 454
# 418 / 454
# 419 / 454
# 420 / 454
# 421 / 454
# 422 / 454
# 423 / 454
# 424 / 454
# 425 / 454
# 426 / 454
# 427 / 454
# 428 / 454
# 429 / 454
# 430 / 454
# 431 / 454
# 432 / 454
# 433 / 454
# 434 / 454
# 435 / 454
# 436 / 454
# 437 / 454
# 438 / 454
# 439 / 454
# 440 / 454
# 441 / 454
# 442 / 454
# 443 / 454
# 444 / 454
# 445 / 454
# 446 / 454
# 447 / 454
# 448 / 454
# 449 / 454
# 450 / 454
# 451 / 454
# 452 / 454
# 453 / 454

# %%
metcalf_limit_99 = numpy.percentile([x[0] for x in all_score_pairs], 99)
iokr_limit_99 = numpy.percentile([x[1] for x in all_score_pairs], 99)

with open('links_crusemann_99.csv', 'w') as f:
    w = csv.writer(f)
    for i, gcf in enumerate(npl.gcfs):
        print('{}/{}'.format(i, len(npl.gcfs)))
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
        raw_metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)

        for mf in npl.molfams:
            try:
                molfam_id = mf.family_id
            except AttributeError:
                molfam_id = -1

            for bgc in gcf.bgcs:
                if (bgc, mf) in verified_bgc_mf_links:
                    verified = 1
                else:
                    verified = 0

                if bgc not in kkb_bgc_hits:
                    continue
                    
# 450/454
# 451/454
# 452/454
# 453/454

# %%
established_link_objects
# Out:
# [(BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3737, spectrum_id=72702, strains=9)),
#  (BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3758, spectrum_id=72970, strains=12)),
#  (BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3759, spectrum_id=73005, strains=2)),
#  (BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3672, spectrum_id=70606, strains=3)),
#  (BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3929, spectrum_id=75146, strains=11)),
#  (BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3951, spectrum_id=75653, strains=15)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3737, spectrum_id=72702, strains=9)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3758, spectrum_id=72970, strains=12)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3759, spectrum_id=73005, strains=2)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3672, spectrum_id=70606, strains=3)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3929, spectrum_id=75146, strains=11)),
#  (BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=3951, spectrum_id=75653, strains=15)),
#  (BGC(name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=6149, spectrum_id=120697, strains=1)),
#  (BGC(name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=6157, spectrum_id=121052, strains=1)),
#  (BGC(name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=6174, spectrum_id=121600, strains=1)),
#  (BGC(name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=6182, spectrum_id=122023, strains=1)),
#  (BGC(name=GCA_000514895.KI911494.1.region001, strain=Strain(CNT005) [4 aliases]),
#   Spectrum(id=6216, spectrum_id=123724, strains=0)),
#  (BGC(name=GCA_000514895.KI911494.1.region001, strain=Strain(CNT005) [4 aliases]),
#   Spectrum(id=6218, spectrum_id=123881, strains=0)),
#  (BGC(name=GCA_000514895.KI911494.1.region001, strain=Strain(CNT005) [4 aliases]),
#   Spectrum(id=6220, spectrum_id=123903, strains=0)),
#  (BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=1651, spectrum_id=41257, strains=53)),
#  (BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=1682, spectrum_id=41544, strains=60)),
#  (BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=1862, spectrum_id=44160, strains=39)),
#  (BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=1863, spectrum_id=44161, strains=41)),
#  (BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   Spectrum(id=1897, spectrum_id=44982, strains=11)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=2864, spectrum_id=58728, strains=4)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3052, spectrum_id=62174, strains=3)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3143, spectrum_id=63507, strains=2)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3159, spectrum_id=63775, strains=4)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3281, spectrum_id=65471, strains=6)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3329, spectrum_id=66182, strains=3)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3356, spectrum_id=66400, strains=3)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3462, spectrum_id=67887, strains=3)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=3525, spectrum_id=68743, strains=3)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=4976, spectrum_id=93193, strains=2)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=5445, spectrum_id=99743, strains=4)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=5532, spectrum_id=100852, strains=4)),
#  (BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   Spectrum(id=5547, spectrum_id=101071, strains=2)),
#  (BGC(name=GCA_000016425.CP000667.1.region006, strain=Strain(CNB440) [5 aliases]),
#   Spectrum(id=4077, spectrum_id=77475, strains=8)),
#  (BGC(name=GCA_000016425.CP000667.1.region006, strain=Strain(CNB440) [5 aliases]),
#   Spectrum(id=4491, spectrum_id=84491, strains=6))]

# %%
all_score_pairs
verified_score_pairs
# Out:
# [(0.2788645161472886, 0.019640809795183234),
#  (0.34909569005526553, 0.010993248952730508),
#  (3.100296637689584, 0.11520462447057787),
#  (-0.11218650701836204, 0.0527926437506062),
#  (2.3793466167370627, 0.019640809795183234),
#  (3.2420501680565126, 0.010993248952730508),
#  (7.61577310586637, 0.0043872040533415365),
#  (0.0, 0.00790119990369821),
#  (7.170580248945476, 0.04846621221771962),
#  (8.305367567710885, 0.05211431009877435),
#  (1.7013995762966228, 0.11520462447057787),
#  (0.30867997771552724, 0.0527926437506062),
#  (2.0681324215457253, 0.019640809795183234),
#  (2.396792985472602, 0.010993248952730508),
#  (5.454622241295362, 0.009440556843367729)]

# %%
import scipy

# %%
iokr_scores_all = [x[1] for x in all_score_pairs if x[1] != -100]
iokr_scores_valid = [x[1] for x in verified_score_pairs if x[1] != -100]
print('Mean IOKR all: {}'.format(numpy.mean(iokr_scores_all)))
print('Mean IOKR valid: {}'.format(numpy.mean(iokr_scores_valid)))
print('IOKR difference in means p-value: {}'.format(scipy.stats.ttest_ind(iokr_scores_all, iokr_scores_valid)))
# Out:
# Mean IOKR all: 0.010650065488149058
# Mean IOKR valid: 0.03668041305353406
# IOKR difference in means p-value: Ttest_indResult(statistic=-6.013251322359768, pvalue=1.8190152592103703e-09)

# %%
metcalf_scores_all = [x[0] for x in all_score_pairs if x[1] != -100]
metcalf_scores_valid = [x[0] for x in verified_score_pairs if x[1] != -100]
print('Mean Metcalf all: {}'.format(numpy.mean(metcalf_scores_all)))
print('Mean Metcalf valid: {}'.format(numpy.mean(metcalf_scores_valid)))
print('Metcalf difference in means p-value: {}'.format(scipy.stats.ttest_ind(metcalf_scores_all, metcalf_scores_valid)))
# Out:
# Mean Metcalf all: -0.006852202755015838
# Mean Metcalf valid: 2.9505876831010616
# Metcalf difference in means p-value: Ttest_indResult(statistic=-13.90148114612521, pvalue=6.263233437841528e-44)

# %%
test_percentile = 95
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

total_link_ratio = len(iokr_scores_valid) / len(iokr_scores_all)

iokr_percentile_ratio = len([x for x in iokr_scores_valid if x >= iokr_percentile]) / len([x for x in iokr_scores_all if x >= iokr_percentile])
metcalf_percentile_ratio = len([x for x in metcalf_scores_valid if x >= metcalf_percentile]) / len([x for x in metcalf_scores_all if x >= metcalf_percentile])

both_percentile_ratio = len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]) / len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile])

print('Total ratio: {}'.format(total_link_ratio))
print('IOKR ratio: {}'.format(iokr_percentile_ratio))
print('Metcalf ratio: {}'.format(metcalf_percentile_ratio))
print('Combined ratio: {}'.format(both_percentile_ratio))
# Out:
# Total ratio: 1.5009576109557898e-05
# IOKR ratio: 0.00012007204322593557
# Metcalf ratio: 0.00019910799617712648
# Combined ratio: 0.0015891934843067143

# %%
test_percentile = 95
iokr_percentile = numpy.percentile(iokr_scores_all, test_percentile)
metcalf_percentile = numpy.percentile(metcalf_scores_all, test_percentile)

print('raw valid', len(iokr_scores_valid))
print('raw all', len(iokr_scores_all))
print('iokr valid', len([x for x in iokr_scores_valid if x >= iokr_percentile]))
print('iokr all', len([x for x in iokr_scores_all if x >= iokr_percentile]))
print('metcalf valid', len([x for x in metcalf_scores_valid if x >= metcalf_percentile]))
print('metcalf all', len([x for x in metcalf_scores_all if x >= metcalf_percentile]))
print('both valid', len([x for x in verified_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
print('both all', len([x for x in all_score_pairs if x[0] >= metcalf_percentile and x[1] >= iokr_percentile]))
# Out:
# raw valid 15
# raw all 999362
# iokr valid 6
# iokr all 49970
# metcalf valid 10
# metcalf all 50224
# both valid 4
# both all 2517

# %%
filename = '20200402_graph_combined_data_iokr_metcalf'

plot = sns.jointplot([x[0] for x in all_score_pairs if x[1] != -100], [x[1] for x in all_score_pairs if x[1] != -100], alpha=0.1, ratio=2, height=12)
plot.ax_joint.plot([x[0] for x in verified_score_pairs if x[1] != -100], [x[1] for x in verified_score_pairs if x[1] != -100], 'ro', color='g')
plot.set_axis_labels('Strain correlation score', 'IOKR score')

data = (all_score_pairs, verified_score_pairs)

with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plot.savefig(filename + '.png')

# %%
# reimport, b/c I accidentally overwrote the other one...
from matplotlib import pyplot as plt

# %%
fig_size = 9.3
fig = plt.figure(figsize=(fig_size, float(fig_size)/2))


# ax_min = -0.15
ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(1, 1, hspace=0.05)

ax1 = plt.subplot(gs[0])
#ax2 = plt.subplot(gs[1])


ax1.hist(metcalf_raw_all_scores, bins=50, range=[ax_min, ax_max], alpha=0.5)
ax1.plot(metcalf_raw_verified_scores, [0]*len(metcalf_raw_verified_scores), '|', color='k', markersize=50)

ax1.set_xlim([ax_min, ax_max])
#ax2.set_xlim([ax_min, ax_max])
#ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_ylabel('count')
ax1.set_xlabel('score')

plt.tight_layout()

plt.savefig('20200511_graph_metcalf_raw_crusemann.pdf')

# %%
plot = sns.jointplot([x[0] for x in all_score_pairs if x[1] != -100], [x[1] for x in all_score_pairs if x[1] != -100], alpha=0.1, ratio=2, height=8, marginal_kws={'hist_kws': {'alpha': 0.5}})
plot.ax_joint.plot([x[0] for x in verified_score_pairs if x[1] != -100], [x[1] for x in verified_score_pairs if x[1] != -100], 'ro', color='r')
# bc horizontal, flip x and y axis
plot.ax_marg_y.plot([0]*len(iokr_scores_valid), iokr_scores_valid, '|', color='k', marker=(2, 0, 90), markersize=50)
plot.ax_marg_x.plot(metcalf_scores_valid, [0]*len(metcalf_scores_valid), '|', color='k', markersize=50)


plot.set_axis_labels('Standardised strain correlation score', 'IOKR score')

filename = '20200514_graph_combined_data_iokr_metcalf'


data = (all_score_pairs, verified_score_pairs)

with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plot.savefig(filename + '.png', dpi=1200)

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure(figsize=(8, 6))

filename = '20200402_graph_iokr_paired_data_crusemann'

# ax_min = -0.15
ax_min = -0.05
# ax_max = 0.35
ax_max = 0.1

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('IOKR score for established links vs. random')

ax1.hist(iokr_scores_all, bins=50, range=[ax_min, ax_max])

ax2.plot(iokr_scores_valid, [5000]*len(iokr_scores_valid), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

data = (iokr_scores_all, iokr_scores_valid)
with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plt.savefig('20200402_graph_iokr_paired_data_crusemann.png')

# %%
fig = plt.figure(figsize=(8, 6))


# ax_min = -0.15
ax_min = min(metcalf_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_all_scores)

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('Strain correlation score for established links vs. random')

ax1.hist(metcalf_scores_all, bins=50, range=[ax_min, ax_max])

ax2.plot(metcalf_scores_valid, [5000]*len(metcalf_scores_valid), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

plt.savefig('graph_metcalf_paired_data_crusemann.png')

# %%
print("Valid links: {}".format(len(metcalf_scores_valid)))
print("Links > 0: {}".format(len([x for x in metcalf_scores_valid if x > 0])))
# Out:
# Valid links: 15
# Links > 0: 13

# %%
metcalf_raw_all_scores = []
metcalf_raw_verified_scores = []

for i, gcf in enumerate(npl.gcfs):
    print("{} / {}".format(i, len(npl.gcfs)))
    
    for mf in npl.molfams:
        metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)
        
        metcalf_raw_all_scores.append(metcalf_score)
        for link_bgc, link_mf in verified_bgc_mf_links:
            if link_bgc in gcf.bgcs and link_mf == mf:
                print('add verified')
                metcalf_raw_verified_scores.append(metcalf_score)
# Out:
# 0 / 454
# 1 / 454
# 2 / 454
# 3 / 454
# 4 / 454
# 5 / 454
# 6 / 454
# 7 / 454
# 8 / 454
# 9 / 454
# 10 / 454
# 11 / 454
# 12 / 454
# 13 / 454
# 14 / 454
# 15 / 454
# 16 / 454
# 17 / 454
# 18 / 454
# 19 / 454
# 20 / 454
# 21 / 454
# 396 / 454
# 397 / 454
# 398 / 454
# 399 / 454
# 400 / 454
# 401 / 454
# 402 / 454
# 403 / 454
# 404 / 454
# 405 / 454
# 406 / 454
# 407 / 454
# 408 / 454
# 409 / 454
# 410 / 454
# 411 / 454
# 412 / 454
# 413 / 454
# 414 / 454
# 415 / 454
# 416 / 454
# 417 / 454
# 418 / 454
# 419 / 454
# 420 / 454
# 421 / 454
# 422 / 454
# 423 / 454
# 424 / 454
# 425 / 454
# 426 / 454
# 427 / 454
# 428 / 454
# 429 / 454
# 430 / 454
# 431 / 454
# 432 / 454
# 433 / 454
# 434 / 454
# 435 / 454
# 436 / 454
# 437 / 454
# 438 / 454
# 439 / 454
# 440 / 454
# 441 / 454
# 442 / 454
# 443 / 454
# 444 / 454
# 445 / 454
# 446 / 454
# 447 / 454
# 448 / 454
# 449 / 454
# 450 / 454
# 451 / 454
# 452 / 454
# 453 / 454

# %%
fig = plt.figure(figsize=(8, 6))


# ax_min = -0.15
ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(2, 1, height_ratios=[20, 2], hspace=0.05)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.set_title('Raw strain correlation score for established links vs. random')

ax1.hist(metcalf_raw_all_scores, bins=50, range=[ax_min, ax_max])

ax2.plot(metcalf_raw_verified_scores, [5000]*len(metcalf_raw_verified_scores), '|', color='k', markersize=50)
ax1.set_xlim([ax_min, ax_max])
ax2.set_xlim([ax_min, ax_max])
ax1.set_xticks([])
ax2.set_yticks([])

ax1.set_ylabel('count')
ax2.set_xlabel('score')

plt.tight_layout()

plt.savefig('graph_metcalf_raw_paired_data_crusemann.png')

# %%
metcalf_raw_scores_all = [x for x, y in zip(metcalf_raw_all_scores, all_score_pairs) if y[1] != -100]
metcalf_raw_scores_valid = [x for x, y in zip(metcalf_raw_verified_scores, verified_score_pairs) if y[1] != -100]
print('Mean Metcalf all: {}'.format(numpy.mean(metcalf_raw_scores_all)))
print('Mean Metcalf valid: {}'.format(numpy.mean(metcalf_raw_scores_valid)))
print('Metcalf difference in means p-value: {}'.format(scipy.stats.ttest_ind(metcalf_raw_scores_all, metcalf_raw_scores_valid)))
# Out:
# Mean Metcalf all: 84.19524256475631
# Mean Metcalf valid: 14.0
# Metcalf difference in means p-value: Ttest_indResult(statistic=3.9408053673283527, pvalue=8.121401609179454e-05)

# %%
with open('20200402_crusemann_metcalf_iokr_verified.bin', 'wb') as f:
    pickle.dump((iokr_scores_all, 
                 iokr_scores_valid, 
                 metcalf_scores_all, 
                 metcalf_scores_valid, 
                 metcalf_raw_scores_all, 
                 metcalf_raw_scores_valid,
                 all_score_pairs,
                 verified_score_pairs), f)

# %%
fig = plt.figure(figsize=(8, 4))

filename = '20200514_raw_vs_standardised_correlation_score_crusemann'

# ax_min = -0.15
raw_ax_min = min(metcalf_raw_all_scores)
# ax_max = 0.35
raw_ax_max = max(metcalf_raw_all_scores)

gs = gridspec.GridSpec(2, 2, height_ratios=[20, 2], hspace=0.05)
raw_hist = plt.subplot(gs[0])
raw_ticks = plt.subplot(gs[2])

raw_hist.set_title('Raw')

raw_hist.hist(metcalf_raw_scores_all, bins=50, range=[raw_ax_min, raw_ax_max])

raw_ticks.plot(metcalf_raw_scores_valid, [5000]*len(metcalf_raw_scores_valid), '|', color='k', markersize=50)
raw_hist.set_xlim([raw_ax_min, raw_ax_max])
raw_ticks.set_xlim([raw_ax_min, raw_ax_max])
raw_hist.set_xticks([])
raw_ticks.set_yticks([])

raw_hist.set_ylabel('count')
raw_ticks.set_xlabel('score')

# raw_hist.yaxis.tick_left()


# ax_min = -0.15
std_ax_min = min(metcalf_scores_all)
# ax_max = 0.35
std_ax_max = max(metcalf_scores_all)


std_hist = plt.subplot(gs[1])
std_ticks = plt.subplot(gs[3])

std_hist.set_title('Standardised')

std_hist.hist(metcalf_scores_all, bins=50, range=[std_ax_min, std_ax_max])

std_ticks.plot(metcalf_scores_valid, [5000]*len(metcalf_scores_valid), '|', color='k', markersize=50)
std_hist.set_xlim([std_ax_min, std_ax_max])
std_ticks.set_xlim([std_ax_min, std_ax_max])
std_hist.set_xticks([])
std_ticks.set_yticks([])

#ax1.set_yticks([])
#std_hist.yaxis.tick_right()
std_hist.set_yticklabels([])

# ax1.set_ylabel('count')
std_ticks.set_xlabel('score')

hist_max = max(std_hist.get_ylim()[1], raw_hist.get_ylim()[1])
std_hist.set_ylim(top=hist_max)
raw_hist.set_ylim(top=hist_max)


plt.tight_layout()

data = (metcalf_raw_all_scores, metcalf_raw_verified_scores, metcalf_scores_all, metcalf_scores_valid)
with open(filename + '.bin', 'wb') as f:
    pickle.dump(data, f)

plt.savefig(filename + '.pdf')

# %%
print(len(metcalf_scores_all))
print(len(metcalf_raw_all_scores))
print(len(_metcalf_raw_scores_all))
# Out:
# 999362
# 1404676
# 999362

# %%
scores_from_bgc = []
scores_from_bgc_idlist = []

for (valid_bgc, valid_mf), mibig_id in zip(verified_bgc_mf_links, verified_bgc_mf_links_labels):
    for gcf in npl.gcfs:
        if valid_bgc in gcf.bgcs:
            iokr_score_list = []
            metcalf_score_list = []
            raw_metcalf_score_list = []
            for mf in npl.molfams:
                iokr_score = get_iokr_score(mf, gcf)
                iokr_score_list.append(iokr_score)
                raw_metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=False)
                raw_metcalf_score_list.append(raw_metcalf_score)
                metcalf_score = misc.metcalf_scoring(mf, gcf, strains, standardised=True)
                metcalf_score_list.append(metcalf_score)
                if mf == valid_mf:
                    valid_iokr_score = iokr_score
                    valid_metcalf_score = metcalf_score
                    valid_raw_metcalf_score = raw_metcalf_score
            scores_from_bgc.append((
                (iokr_score_list, valid_iokr_score),
                (metcalf_score_list, valid_metcalf_score),
                (raw_metcalf_score_list, valid_raw_metcalf_score)
            ))
                
            scores_from_bgc_idlist.append((gcf, valid_bgc, mibig_id))

# %%
scores_from_bgc_idlist
# Out:
# [(GCF(id=71, class=NRPS, gcf_id=980, strains=26),
#   BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=333, class=PKS-NRP, gcf_id=863, strains=16),
#   BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=71, class=NRPS, gcf_id=980, strains=26),
#   BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=333, class=PKS-NRP, gcf_id=863, strains=16),
#   BGC(name=GCA_000018265.CP000850.1.region022, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=48, class=NRPS, gcf_id=767, strains=10),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=123, class=NRPS, gcf_id=2015, strains=2),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=367, class=PKSother, gcf_id=2512, strains=9),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=48, class=NRPS, gcf_id=767, strains=10),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=123, class=NRPS, gcf_id=2015, strains=2),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=367, class=PKSother, gcf_id=2512, strains=9),
#   BGC(name=GCA_000018265.CP000850.1.region006, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000137'),
#  (GCF(id=132, class=NRPS, gcf_id=2241, strains=2),
#   BGC(name=GCA_000018265.CP000850.1.region024, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000333'),
#  (GCF(id=161, class=NRPS, gcf_id=2865, strains=1),
#   BGC(name=GCA_000514895.KI911494.1.region001, strain=Strain(CNT005) [4 aliases]),
#   'BGC0001228'),
#  (GCF(id=232, class=Others, gcf_id=2864, strains=61),
#   BGC(name=GCA_000018265.CP000850.1.region012, strain=Strain(CNS205) [5 aliases]),
#   'BGC0000827'),
#  (GCF(id=295, class=PKSI, gcf_id=2151, strains=3),
#   BGC(name=GCA_000424905.AUGH01000019.1.region001, strain=Strain(CNS237) [4 aliases]),
#   'BGC0001830'),
#  (GCF(id=377, class=PKSother, gcf_id=3067, strains=15),
#   BGC(name=GCA_000016425.CP000667.1.region006, strain=Strain(CNB440) [5 aliases]),
#   'BGC0000241')]

# %%
sample_plot_indices = [10, 11, 12]

w = 8
h = (25.0 / 15 * 3) / 9 * 8

filename = '20200514_bgc_scores_crusemann'

fig, axes = plt.subplots(nrows=len(sample_plot_indices), ncols=4, figsize=(w, h))

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

for row_idx, sample_idx in enumerate(sample_plot_indices):
    gcf, bgc, mibig = scores_from_bgc_idlist[sample_idx]
    axes[row_idx, 0].set_ylabel(mibig)

    initial_bgc = scores_from_bgc[sample_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    ax.set_xticks([])
    ax.set_yticks([])
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.scatter([actual_score], [0], zorder=4, color='r')
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)



fig.tight_layout()

data = (sample_plot_indices, scores_from_bgc_idlist, scores_from_bgc)
with open(filename + '.data', 'wb') as f:
    pickle.dump(data, f)

plt.savefig(filename + '_top.png', dpi=1200)

# %%
dir(ax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_current_image',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
#  '_hold',
#  '_in_layout',
#  '_init_axis',
#  '_label',
#  '_layoutbox',
#  '_left_title',
#  '_make_twin_axes',
#  '_mouseover',
#  '_mouseover_set',
#  '_navigate',
#  '_navigate_mode',
#  '_oid',
#  '_on_units_changed',
#  '_originalPosition',
#  '_path_effects',
#  '_pcolorargs',
#  '_picker',
#  '_position',
#  '_poslayoutbox',
#  '_process_unit_info',
#  '_prop_order',
#  '_propobservers',
#  '_quiver_units',
#  '_rasterization_zorder',
#  '_rasterized',
#  '_remove_legend',
#  '_remove_method',
#  '_right_title',
#  '_sci',
#  '_set_artist_props',
#  '_set_gc_clip',
#  '_set_lim_and_transforms',
#  '_set_position',
#  '_set_title_offset_trans',
#  '_set_view',
#  '_set_view_from_bbox',
#  '_shared_x_axes',
#  '_shared_y_axes',
#  '_sharex',
#  '_sharey',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_sticky_edges',
#  '_subplotspec',
#  '_tight',
#  '_transform',
#  '_transformSet',
#  '_twinned_axes',
#  '_update_image_limits',
#  '_update_line_limits',
#  '_update_patch_limits',
#  '_update_title_position',
#  '_update_transScale',
#  '_url',
#  '_use_sticky_edges',
#  '_validate_converted_limits',
#  '_visible',
#  '_xaxis_transform',
#  '_xcid',
#  '_xmargin',
#  '_yaxis_transform',
#  '_ycid',
#  '_ymargin',
#  'acorr',
#  'add_artist',
#  'add_callback',
#  'add_child_axes',
#  'add_collection',
#  'add_container',
#  'add_image',
#  'add_line',
#  'add_patch',
#  'add_table',
#  'aname',
#  'angle_spectrum',
#  'annotate',
#  'apply_aspect',
#  'arrow',
#  'artists',
#  'autoscale',
#  'autoscale_view',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axison',
#  'axvline',
#  'axvspan',
#  'bar',
#  'barbs',
#  'barh',
#  'bbox',
#  'boxplot',
#  'broken_barh',
#  'bxp',
#  'callbacks',
#  'can_pan',
#  'can_zoom',
#  'change_geometry',
#  'child_axes',
#  'cla',
#  'clabel',
#  'clear',
#  'clipbox',
#  'cohere',
#  'colNum',
#  'collections',
#  'containers',
#  'contains',
#  'contains_point',
#  'contour',
#  'contourf',
#  'convert_xunits',
#  'convert_yunits',
#  'csd',
#  'dataLim',
#  'drag_pan',
#  'draw',
#  'draw_artist',
#  'end_pan',
#  'errorbar',
#  'eventplot',
#  'eventson',
#  'figbox',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'fmt_xdata',
#  'fmt_ydata',
#  'format_coord',
#  'format_cursor_data',
#  'format_xdata',
#  'format_ydata',
#  'get_adjustable',
#  'get_agg_filter',
#  'get_alpha',
#  'get_anchor',
#  'get_animated',
#  'get_aspect',
#  'get_autoscale_on',
#  'get_autoscalex_on',
#  'get_autoscaley_on',
#  'get_axes_locator',
#  'get_axisbelow',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_contains',
#  'get_cursor_data',
#  'get_data_ratio',
#  'get_data_ratio_log',
#  'get_default_bbox_extra_artists',
#  'get_facecolor',
#  'get_fc',
#  'get_figure',
#  'get_frame_on',
#  'get_geometry',
#  'get_gid',
#  'get_gridspec',
#  'get_images',
#  'get_in_layout',
#  'get_label',
#  'get_legend',
#  'get_legend_handles_labels',
#  'get_lines',
#  'get_navigate',
#  'get_navigate_mode',
#  'get_path_effects',
#  'get_picker',
#  'get_position',
#  'get_rasterization_zorder',
#  'get_rasterized',
#  'get_renderer_cache',
#  'get_shared_x_axes',
#  'get_shared_y_axes',
#  'get_sketch_params',
#  'get_snap',
#  'get_subplotspec',
#  'get_tightbbox',
#  'get_title',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xaxis',
#  'get_xaxis_text1_transform',
#  'get_xaxis_text2_transform',
#  'get_xaxis_transform',
#  'get_xbound',
#  'get_xgridlines',
#  'get_xlabel',
#  'get_xlim',
#  'get_xmajorticklabels',
#  'get_xminorticklabels',
#  'get_xscale',
#  'get_xticklabels',
#  'get_xticklines',
#  'get_xticks',
#  'get_yaxis',
#  'get_yaxis_text1_transform',
#  'get_yaxis_text2_transform',
#  'get_yaxis_transform',
#  'get_ybound',
#  'get_ygridlines',
#  'get_ylabel',
#  'get_ylim',
#  'get_ymajorticklabels',
#  'get_yminorticklabels',
#  'get_yscale',
#  'get_yticklabels',
#  'get_yticklines',
#  'get_yticks',
#  'get_zorder',
#  'grid',
#  'has_data',
#  'have_units',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hitlist',
#  'hlines',
#  'ignore_existing_data_limits',
#  'images',
#  'imshow',
#  'in_axes',
#  'indicate_inset',
#  'indicate_inset_zoom',
#  'inset_axes',
#  'invert_xaxis',
#  'invert_yaxis',
#  'is_figure_set',
#  'is_first_col',
#  'is_first_row',
#  'is_last_col',
#  'is_last_row',
#  'is_transform_set',
#  'label_outer',
#  'legend',
#  'legend_',
#  'lines',
#  'locator_params',
#  'loglog',
#  'magnitude_spectrum',
#  'margins',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mouseover',
#  'mouseover_set',
#  'name',
#  'numCols',
#  'numRows',
#  'patch',
#  'patches',
#  'pchanged',
#  'pcolor',
#  'pcolorfast',
#  'pcolormesh',
#  'phase_spectrum',
#  'pick',
#  'pickable',
#  'pie',
#  'plot',
#  'plot_date',
#  'properties',
#  'psd',
#  'quiver',
#  'quiverkey',
#  'redraw_in_frame',
#  'relim',
#  'remove',
#  'remove_callback',
#  'reset_position',
#  'rowNum',
#  'scatter',
#  'semilogx',
#  'semilogy',
#  'set',
#  'set_adjustable',
#  'set_agg_filter',
#  'set_alpha',
#  'set_anchor',
#  'set_animated',
#  'set_aspect',
#  'set_autoscale_on',
#  'set_autoscalex_on',
#  'set_autoscaley_on',
#  'set_axes_locator',
#  'set_axis_off',
#  'set_axis_on',
#  'set_axisbelow',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_contains',
#  'set_facecolor',
#  'set_fc',
#  'set_figure',
#  'set_frame_on',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_navigate',
#  'set_navigate_mode',
#  'set_path_effects',
#  'set_picker',
#  'set_position',
#  'set_prop_cycle',
#  'set_rasterization_zorder',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_subplotspec',
#  'set_title',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xbound',
#  'set_xlabel',
#  'set_xlim',
#  'set_xmargin',
#  'set_xscale',
#  'set_xticklabels',
#  'set_xticks',
#  'set_ybound',
#  'set_ylabel',
#  'set_ylim',
#  'set_ymargin',
#  'set_yscale',
#  'set_yticklabels',
#  'set_yticks',
#  'set_zorder',
#  'specgram',
#  'spines',
#  'spy',
#  'stackplot',
#  'stale',
#  'stale_callback',
#  'start_pan',
#  'stem',
#  'step',
#  'sticky_edges',
#  'streamplot',
#  'table',
#  'tables',
#  'text',
#  'texts',
#  'tick_params',
#  'ticklabel_format',
#  'title',
#  'titleOffsetTrans',
#  'transAxes',
#  'transData',
#  'transLimits',
#  'transScale',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'update',
#  'update_datalim',
#  'update_datalim_bounds',
#  'update_from',
#  'update_params',
#  'use_sticky_edges',
#  'viewLim',
#  'violin',
#  'violinplot',
#  'vlines',
#  'xaxis',
#  'xaxis_date',
#  'xaxis_inverted',
#  'xcorr',
#  'yaxis',
#  'yaxis_date',
#  'yaxis_inverted',
#  'zorder']

# %%
fig, axes = plt.subplots(nrows=15, ncols=4, figsize=(9, 25))

filename = '20200420_bgc_scores_crusemann'

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

for row_idx in range(len(scores_from_bgc)):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    axes[row_idx, 0].set_ylabel(mibig)


    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    ax.set_xticks([])
    ax.set_yticks([])
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        ax.set_xticks([])
        ax.set_yticks([])
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
# 15 in total -- 8 + 7
# first part
nrows = 8
figheight = 25 / 15 * nrows
fig, axes = plt.subplots(nrows=nrows, ncols=4, figsize=(9, figheight))

filename = '20200518_bgc_scores_crusemann_part1'

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

#for row_idx in range(len(scores_from_bgc)):
for row_idx in range(8):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    axes[row_idx, 0].set_ylabel(mibig)


    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    ax.set_xticks([])
    ax.set_yticks([])
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        ax.set_xticks([])
        ax.set_yticks([])
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
# second part
row_offset = 8
nrows = 7
figheight = 25 / 15 * nrows
fig, axes = plt.subplots(nrows=nrows, ncols=4, figsize=(9, figheight))

filename = '20200518_bgc_scores_crusemann_part2'

#cols = ['IOKR', 'Standardised strain correlation', 'Raw strain correlation']
cols = ['Raw corr.', 'Std. corr.', 'IOKR', 'Corr. vs IOKR']
for ax, col in zip(axes[0], cols):
    ax.set_title(col)

#for row_idx in range(len(scores_from_bgc)):
graph_row_idx = 0
for row_idx in range(8, 15):
    gcf, bgc, mibig = scores_from_bgc_idlist[row_idx]
    axes[graph_row_idx, 0].set_ylabel(mibig)

    initial_bgc = scores_from_bgc[row_idx]
    score_set_metcalf, actual_score_metcalf = initial_bgc[1]
    score_set_iokr, actual_score_iokr = initial_bgc[0]
    ax = axes[graph_row_idx, 3]
    ax.scatter(score_set_metcalf, score_set_iokr, alpha=0.05)
    ax.scatter([actual_score_metcalf], [actual_score_iokr], color='r')
    ax.set_xticks([])
    ax.set_yticks([])
    
    max_ylim = 0
    min_ylim = 0
    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        # invert col. order
        col_idx = 2 - col_idx
        ax = axes[graph_row_idx, col_idx]
        ax.hist(score_set)
        ax.scatter([actual_score], [0], zorder=3, color='r')
        ax.set_xticks([])
        ax.set_yticks([])
        min_ylim = ax.get_ylim()[0]
        max_ylim = max(max_ylim, ax.get_ylim()[1])

    for col_idx, (score_set, actual_score) in enumerate(initial_bgc):
        ax = axes[graph_row_idx, col_idx]
        ax.set_ylim(min_ylim, max_ylim)
        
    graph_row_idx += 1

fig.tight_layout()

plt.savefig(filename + '_all.png')

# %%
dir(misc)
# Out:
# ['METCALF_EXPECTED_CACHE',
#  'METCALF_VARIANCE_CACHE',
#  'METCALF_WEIGHTS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'aa_scoring',
#  'expand_spectrum_score',
#  'hg_scoring',
#  'knownclusterblast_scoring',
#  'match',
#  'metcalf_count',
#  'metcalf_expected_count',
#  'metcalf_scoring',
#  'metcalf_std_count',
#  'name_scoring',
#  'np',
#  'scipy']

# %%
misc.metcalf_scoring
print('metcalf_raw', misc.metcalf_count(3, 8, 3, 8, 10, -10, 0, 1))
print('metcalf_raw', misc.metcalf_count(2, 2, 2, 8, 10, -10, 0, 1))
print('metcalf_std', misc.metcalf_std_count(3, 8, 3, 8, 10, -10, 0, 1))
print('metcalf_std', misc.metcalf_std_count(2, 2, 2, 8, 10, -10, 0, 1))
# Out:
# metcalf_raw 30
# metcalf_raw 26
# metcalf_std 0.0
# metcalf_std 2.645751311064591
